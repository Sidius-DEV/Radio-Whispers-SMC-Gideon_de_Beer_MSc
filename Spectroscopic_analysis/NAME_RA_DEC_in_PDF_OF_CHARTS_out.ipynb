# %%
#Check observability in Sutherland, and create finder charts to be used during observing run

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from astropy.coordinates import SkyCoord, EarthLocation, AltAz
from astropy.time import Time
import astropy.units as u
from astroplan import Observer, FixedTarget, AirmassConstraint, AtNightConstraint
from astroplan.constraints import (TimeConstraint, AirmassConstraint, AtNightConstraint)
from astroplan.plots import plot_airmass

# Load data from CSV
data = pd.read_csv('targets.csv')
dataCoords=[]
for i in range(0,len(data['RA'])):
    print(SkyCoord(str(data['RA'][i])+" "+str(data['Dec'][i]), unit=(u.hourangle, u.deg)))
    dataCoords.append(SkyCoord(str(data['RA'][i])+" "+str(data['Dec'][i]), unit=(u.hourangle, u.deg)))
    print(dataCoords[i].ra, dataCoords[i].dec)
#     print(data['RA'][i]*u.hourangle)

# Sutherland Observatory location
sutherland = Observer(longitude=20.810443*u.deg, latitude=-32.376749*u.deg, elevation=1800*u.m, name="Sutherland")

# Observation time (for example, tonight)
observation_time = Time('2023-11-16T19:00:00')  

# Constraints for the observation plan
constraints = [AirmassConstraint(2.5), AtNightConstraint.twilight_civil()]

# Loop through the targets and create an observing plan
for i in range(0,len(data['RA'])):
    # Create a target object
    target_coord = SkyCoord(ra=dataCoords[i].ra, dec=dataCoords[i].dec)
    target = FixedTarget(coord=target_coord, name=data['Name'][i])


#     start_time = Time('2023-11-15 19:00:00')
#     end_time = Time('2023-11-16 06:00:00')
#     start_time = Time('2023-11-16 19:00:00')
#     end_time = Time('2023-11-17 06:00:00')
#     start_time = Time('2023-11-17 19:00:00')
#     end_time = Time('2023-11-18 06:00:00')
#     start_time = Time('2023-11-18 19:00:00')
#     end_time = Time('2023-11-19 06:00:00')
#     start_time = Time('2023-11-19 19:00:00')
#     end_time = Time('2023-11-20 06:00:00')
#     start_time = Time('2023-11-20 19:00:00')
#     end_time = Time('2023-11-21 06:00:00')
    start_time = Time('2023-11-21 19:00:00')
    end_time = Time('2023-11-22 06:00:00')

    delta_t = end_time - start_time

    observe_time = start_time + delta_t*np.linspace(0, 1, 75)

    plot_airmass(target, sutherland, observe_time)

plt.show()
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (17.58279167, -72.05986389)>
# 17d34m58.05s -72d03m35.51s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (15.40816667, -71.90467778)>
# 15d24m29.4s -71d54m16.84s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (21.21154167, -73.96106944)>
# 21d12m41.55s -73d57m39.85s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (15.74041667, -72.52938333)>
# 15d44m25.5s -72d31m45.78s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (20.744, -73.991275)>
# 20d44m38.4s -73d59m28.59s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (14.89058333, -72.34716667)>
# 14d53m26.1s -72d20m49.8s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (15.974625, -72.14078611)>
# 15d58m28.65s -72d08m26.83s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (16.90091667, -72.58014444)>
# 16d54m03.3s -72d34m48.52s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (15.24245833, -71.59164722)>
# 15d14m32.85s -71d35m29.93s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (21.14616667, -73.63207222)>
# 21d08m46.2s -73d37m55.46s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (16.84220833, -71.827075)>
# 16d50m31.95s -71d49m37.47s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (17.16745833, -71.98048056)>
# 17d10m02.85s -71d58m49.73s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (16.06633333, -71.82317778)>
# 16d03m58.8s -71d49m23.44s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (14.81745833, -72.03355556)>
# 14d49m02.85s -72d02m00.8s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (16.12204167, -71.76556667)>
# 16d07m19.35s -71d45m56.04s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (21.670625, -72.99436667)>
# 21d40m14.25s -72d59m39.72s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (21.22716667, -73.64261667)>
# 21d13m37.8s -73d38m33.42s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (17.22795833, -72.20222778)>
# 17d13m40.65s -72d12m08.02s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (14.67895833, -72.45488056)>
# 14d40m44.25s -72d27m17.57s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (16.50670833, -72.06008056)>
# 16d30m24.15s -72d03m36.29s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (19.98416667, -73.36495833)>
# 19d59m03s -73d21m53.85s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (22.79529167, -73.38845278)>
# 22d47m43.05s -73d23m18.43s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (15.54995833, -71.81418611)>
# 15d32m59.85s -71d48m51.07s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (14.54975, -71.46722222)>
# 14d32m59.1s -71d28m02s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (21.991375, -73.375875)>
# 21d59m28.95s -73d22m33.15s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (22.40395833, -73.67650278)>
# 22d24m14.25s -73d40m35.41s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (14.32970833, -72.55055278)>
# 14d19m46.95s -72d33m01.99s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (21.04970833, -74.04251111)>
# 21d02m58.95s -74d02m33.04s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (15.50533333, -72.37206944)>
# 15d30m19.2s -72d22m19.45s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (17.56345833, -72.03661944)>
# 17d33m48.45s -72d02m11.83s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (21.28466667, -73.77058056)>
# 21d17m04.8s -73d46m14.09s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (16.56279167, -72.33014722)>
# 16d33m46.05s -72d19m48.53s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (23.127625, -73.21038611)>
# 23d07m39.45s -73d12m37.39s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (15.02520833, -71.95191944)>
# 15d01m30.75s -71d57m06.91s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (16.13495833, -72.07887778)>
# 16d08m05.85s -72d04m43.96s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (15.92783333, -72.35031389)>
# 15d55m40.2s -72d21m01.13s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (15.86866667, -72.497325)>
# 15d52m07.2s -72d29m50.37s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (16.37829167, -72.28391389)>
# 16d22m41.85s -72d17m02.09s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (15.534625, -72.11353889)>
# 15d32m04.65s -72d06m48.74s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (14.38670833, -72.21744167)>
# 14d23m12.15s -72d13m02.79s
# <SkyCoord (ICRS): (ra, dec) in deg
#     (16.03004167, -71.61171667)>
# 16d01m48.15s -71d36m42.18s
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]

# %%
# Create finder chart pdfs, and merge into single pdf

from PyPDF2 import PdfMerger
import pandas as pd
from astroquery.skyview import SkyView
import astropy.units as u
from astropy.coordinates import SkyCoord
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# Read the CSV file with names, RA and Dec coordinates
data = pd.read_csv('targets.csv')  # Replace 'targets.csv' with your CSV file name
Name_list = data['Name']
ra_list = data['RA']  # Assuming the column names in the CSV are 'Name', 'RA' and 'Dec'
dec_list = data['Dec']
FileNames=[]
merger = PdfMerger()

# Function to display cutout and mark target coordinates
def display_cutout(name, ra, dec):
    center = SkyCoord(ra=(str(ra)+' hours'), dec=str(dec+' degree'), frame='icrs')
    size = u.Quantity(5, u.arcmin)
    
    # print("surveys: ",SkyView.list_surveys()) #This gives a list of available surveys to replace survey=['DSS'] if desired
    images = SkyView.get_images(position=center, survey=['DSS'], height=size, width=size)
    img_data = images[0][0].data

    fig, ax = plt.subplots(figsize=(8, 8))
    ax.imshow(img_data, origin='upper', cmap='gray', extent=(0, size.to(u.deg).value, 0, size.to(u.deg).value))

    # Mark target coordinates with a reticle
    rect = Rectangle((2.5/60, 2.5/60), 5/60, 5/60, linewidth=0.5, edgecolor='red', facecolor='none')
    ax.add_patch(rect)
    ax.invert_yaxis()

#     plt.xlabel('RA (degrees)', color='w')
#     plt.ylabel('DEC (degrees)', color='w')
    plt.xticks(color='w')
    plt.yticks(color='w')
    plt.title('Finder for '+str(name))
#     plt.plot()
    plt.savefig(r"./charts/"+str(name)+'.pdf', dpi=800)
    plt.close()
    FileNames.append("./charts/"+str(name)+'.pdf')

# Display cutouts and mark target coordinates
for name, ra, dec in zip(Name_list, ra_list, dec_list):
    display_cutout(name, ra, dec)

print(FileNames)
for pdf in FileNames:
    merger.append(pdf)
merger.write("./charts/"+'All_Charts.pdf')
merger.close()
# Out:
# {'Allbands:GOODS/HDF/CDF': ['GOODS: Chandra ACIS HB',
#                             'GOODS: Chandra ACIS FB',
#                             'GOODS: Chandra ACIS SB',
#                             'GOODS: VLT VIMOS U',
#                             'GOODS: VLT VIMOS R',
#                             'GOODS: HST ACS B',
#                             'GOODS: HST ACS V',
#                             'GOODS: HST ACS I',
#                             'GOODS: HST ACS Z',
#                             'Hawaii HDF U',
#                             'Hawaii HDF B',
#                             'Hawaii HDF V0201',
#                             'Hawaii HDF V0401',
#                             'Hawaii HDF R',
#                             'Hawaii HDF I',
#                             'Hawaii HDF z',
#                             'Hawaii HDF HK',
#                             'GOODS: HST NICMOS',
#                             'GOODS: VLT ISAAC J',
#                             'GOODS: VLT ISAAC H',
#                             'GOODS: VLT ISAAC Ks',
#                             'HUDF: VLT ISAAC Ks',
#                             'GOODS: Spitzer IRAC 3.6',
#                             'GOODS: Spitzer IRAC 4.5',
#                             'GOODS: Spitzer IRAC 5.8',
#                             'GOODS: Spitzer IRAC 8.0',
#                             'GOODS: Spitzer MIPS 24',
#                             'GOODS: Herschel 100',
#                             'GOODS: Herschel 160',
#                             'GOODS: Herschel 250',
#                             'GOODS: Herschel 350',
#                             'GOODS: Herschel 500',
#                             'CDFS: LESS',
#                             'GOODS: VLA North'],
#  'Allbands:HiPS': ['UltraVista-H',
#                    'UltraVista-J',
#                    'UltraVista-Ks',
#                    'UltraVista-NB118',
#                    'UltraVista-Y',
#                    'CFHTLS-W-u',
#                    'CFHTLS-W-g',
#                    'CFHTLS-W-r',
#                    'CFHTLS-W-i',
#                    'CFHTLS-W-z',
#                    'CFHTLS-D-u',
#                    'CFHTLS-D-g',
#                    'CFHTLS-D-r',
#                    'CFHTLS-D-i',
#                    'CFHTLS-D-z'],
#  'GammaRay': ['Fermi 5',
#               'Fermi 4',
#               'Fermi 3',
#               'Fermi 2',
#               'Fermi 1',
#               'EGRET (3D)',
#               'EGRET <100 MeV',
#               'EGRET >100 MeV',
#               'COMPTEL'],
#  'HardX-ray': ['INT GAL 17-35 Flux',
#                'INT GAL 17-60 Flux',
#                'INT GAL 35-80 Flux',
#                'INTEGRAL/SPI GC',
#                'GRANAT/SIGMA',
#                'RXTE Allsky 3-8keV Flux',
#                'RXTE Allsky 3-20keV Flux',
#                'RXTE Allsky 8-20keV Flux'],
#  'IR:2MASS class=': ['2MASS-J', '2MASS-H', '2MASS-K'],
#  'IR:AKARI class=': ['AKARI N60', 'AKARI WIDE-S', 'AKARI WIDE-L', 'AKARI N160'],
#  'IR:IRAS': ['IRIS  12',
#              'IRIS  25',
#              'IRIS  60',
#              'IRIS 100',
#              'SFD100m',
#              'SFD Dust Map',
#              'IRAS  12 micron',
#              'IRAS  25 micron',
#              'IRAS  60 micron',
#              'IRAS 100 micron'],
#  'IR:Planck': ['Planck 857 I',
#                'Planck 545 I',
#                'Planck 353 I',
#                'Planck 353 Q',
#                'Planck 353 U',
#                'Planck 353 PI',
#                'Planck 353 PA',
#                'Planck 353 PI/I',
#                'Planck 217 I',
#                'Planck 217 Q',
#                'Planck 217 U',
#                'Planck 217 PI',
#                'Planck 217 PA',
#                'Planck 217 PI/I',
#                'Planck 143 I',
#                'Planck 143 Q',
#                'Planck 143 U',
#                'Planck 143 PI',
#                'Planck 143 PA',
#                'Planck 143 PI/I',
#                'Planck 100 I',
#                'Planck 100 Q',
#                'Planck 100 U',
#                'Planck 100 PI',
#                'Planck 100 PA',
#                'Planck 100 PI/I',
#                'Planck 070 I',
#                'Planck 070 Q',
#                'Planck 070 U',
#                'Planck 070 PI',
#                'Planck 070 PA',
#                'Planck 070 PI/I',
#                'Planck 044 I',
#                'Planck 044 Q',
#                'Planck 044 U',
#                'Planck 044 PI',
#                'Planck 044 PA',
#                'Planck 044 PI/I',
#                'Planck 030 I',
#                'Planck 030 Q',
#                'Planck 030 U',
#                'Planck 030 PI',
#                'Planck 030 PA',
#                'Planck 030 PI/I'],
#  'IR:UKIDSS class=': ['UKIDSS-Y',
#                       'UKIDSS-J',
#                       'UKIDSS-H',
#                       'UKIDSS-K',
#                       'UKIDSS-1-0S1'],
#  'IR:WISE class=': ['WISE 3.4', 'WISE 4.6', 'WISE 12', 'WISE 22'],
#  'IR:WMAP&COBE': ['WMAP ILC',
#                   'WMAP Ka',
#                   'WMAP K',
#                   'WMAP Q',
#                   'WMAP V',
#                   'WMAP W',
#                   'COBE DIRBE/AAM',
#                   'COBE DIRBE/ZSMA'],
#  'Optical:DSS class=': ['DSS',
#                         'DSS1 Blue',
#                         'DSS1 Red',
#                         'DSS2 Red',
#                         'DSS2 Blue',
#                         'DSS2 IR'],
#  'Optical:SDSS': ['SDSSg',
#                   'SDSSi',
#                   'SDSSr',
#                   'SDSSu',
#                   'SDSSz',
#                   'SDSSdr7g',
#                   'SDSSdr7i',
#                   'SDSSdr7r',
#                   'SDSSdr7u',
#                   'SDSSdr7z'],
#  'OtherOptical': ['TESS',
#                   'Mellinger Red',
#                   'Mellinger Green',
#                   'Mellinger Blue',
#                   'H-Alpha Comp',
#                   'SHASSA H',
#                   'SHASSA CC',
#                   'SHASSA C',
#                   'SHASSA Sm'],
#  'ROSATDiffuse class=': ['RASS Background 1',
#                          'RASS Background 2',
#                          'RASS Background 3',
#                          'RASS Background 4',
#                          'RASS Background 5',
#                          'RASS Background 6',
#                          'RASS Background 7'],
#  'ROSATw/sources class=': ['RASS-Cnt Soft',
#                            'RASS-Cnt Hard',
#                            'RASS-Cnt Broad',
#                            'PSPC 2.0 Deg-Int',
#                            'PSPC 1.0 Deg-Int',
#                            'PSPC 0.6 Deg-Int',
#                            'HRI'],
#  'Radio:GHz': ['CO',
#                'GB6 (4850MHz)',
#                'VLA FIRST (1.4 GHz)',
#                'NVSS',
#                'Stripe82VLA',
#                '1420MHz (Bonn)',
#                'HI4PI',
#                'EBHIS',
#                'nH'],
#  'Radio:GLEAM class=': ['GLEAM 72-103 MHz',
#                         'GLEAM 103-134 MHz',
#                         'GLEAM 139-170 MHz',
#                         'GLEAM 170-231 MHz'],
#  'Radio:MHz class=': ['SUMSS 843 MHz',
#                       '0408MHz',
#                       'WENSS',
#                       'TGSS ADR1',
#                       'VLSSr',
#                       '0035MHz',
#                       '0022MHz'],
#  'SoftX-ray class=': ['SwiftXRTCnt',
#                       'SwiftXRTExp',
#                       'SwiftXRTInt',
#                       'HEAO 1 A-2'],
#  'SwiftUVOT class=': ['UVOT WHITE Intensity',
#                       'UVOT V Intensity',
#                       'UVOT B Intensity',
#                       'UVOT U Intensity',
#                       'UVOT UVW1 Intensity',
#                       'UVOT UVM2 Intensity',
#                       'UVOT UVW2 Intensity'],
#  'UV': ['GALEX Near UV',
#         'GALEX Far UV',
#         'ROSAT WFC F1',
#         'ROSAT WFC F2',
#         'EUVE 83 A',
#         'EUVE 171 A',
#         'EUVE 405 A',
#         'EUVE 555 A'],
#  'X-ray:SwiftBAT': ['BAT SNR 14-195',
#                     'BAT SNR 14-20',
#                     'BAT SNR 20-24',
#                     'BAT SNR 24-35',
#                     'BAT SNR 35-50',
#                     'BAT SNR 50-75',
#                     'BAT SNR 75-100',
#                     'BAT SNR 100-150',
#                     'BAT SNR 150-195']}
# surveys:  None
# WARNING: AstropyDeprecationWarning: The truth value of a Quantity is ambiguous. In the future this will raise a ValueError. [astropy.units.quantity]
# {'Allbands:GOODS/HDF/CDF': ['GOODS: Chandra ACIS HB',
#                             'GOODS: Chandra ACIS FB',
#                             'GOODS: Chandra ACIS SB',
#                             'GOODS: VLT VIMOS U',
#                             'GOODS: VLT VIMOS R',
#                             'GOODS: HST ACS B',
#                             'GOODS: HST ACS V',
#                             'GOODS: HST ACS I',
#                             'GOODS: HST ACS Z',
#                             'Hawaii HDF U',
#                             'Hawaii HDF B',
#                             'Hawaii HDF V0201',
#                             'Hawaii HDF V0401',
#                             'Hawaii HDF R',
#                             'Hawaii HDF I',
#                             'Hawaii HDF z',
#                             'Hawaii HDF HK',
#                             'GOODS: HST NICMOS',
#                             'GOODS: VLT ISAAC J',
#                             'GOODS: VLT ISAAC H',
#                             'GOODS: VLT ISAAC Ks',
#                             'HUDF: VLT ISAAC Ks',
#                             'GOODS: Spitzer IRAC 3.6',
#                             'GOODS: Spitzer IRAC 4.5',
#                             'GOODS: Spitzer IRAC 5.8',
#                             'GOODS: Spitzer IRAC 8.0',
#                             'GOODS: Spitzer MIPS 24',
#                             'GOODS: Herschel 100',
#                             'GOODS: Herschel 160',
#                             'GOODS: Herschel 250',
#                             'GOODS: Herschel 350',
#                             'GOODS: Herschel 500',
#                             'CDFS: LESS',
#                             'GOODS: VLA North'],
#  'Allbands:HiPS': ['UltraVista-H',
#                    'UltraVista-J',
#                    'UltraVista-Ks',
#                    'UltraVista-NB118',
#                    'UltraVista-Y',
#                    'CFHTLS-W-u',
#                    'CFHTLS-W-g',
#                    'CFHTLS-W-r',
#                    'CFHTLS-W-i',
#                    'CFHTLS-W-z',
#                    'CFHTLS-D-u',
#                    'CFHTLS-D-g',
#                    'CFHTLS-D-r',
#                    'CFHTLS-D-i',
#                    'CFHTLS-D-z'],
#  'GammaRay': ['Fermi 5',
#               'Fermi 4',
#               'Fermi 3',
#               'Fermi 2',
#               'Fermi 1',
#               'EGRET (3D)',
#               'EGRET <100 MeV',
#               'EGRET >100 MeV',
#               'COMPTEL'],
#  'HardX-ray': ['INT GAL 17-35 Flux',
#                'INT GAL 17-60 Flux',
#                'INT GAL 35-80 Flux',
#                'INTEGRAL/SPI GC',
#                'GRANAT/SIGMA',
#                'RXTE Allsky 3-8keV Flux',
#                'RXTE Allsky 3-20keV Flux',
#                'RXTE Allsky 8-20keV Flux'],
#  'IR:2MASS class=': ['2MASS-J', '2MASS-H', '2MASS-K'],
#  'IR:AKARI class=': ['AKARI N60', 'AKARI WIDE-S', 'AKARI WIDE-L', 'AKARI N160'],
#  'IR:IRAS': ['IRIS  12',
#              'IRIS  25',
#              'IRIS  60',
#              'IRIS 100',
#              'SFD100m',
#              'SFD Dust Map',
#              'IRAS  12 micron',
#              'IRAS  25 micron',
#              'IRAS  60 micron',
#              'IRAS 100 micron'],
#  'IR:Planck': ['Planck 857 I',
#                'Planck 545 I',
#                'Planck 353 I',
#                'Planck 353 Q',
#                'Planck 353 U',
#                'Planck 353 PI',
#                'Planck 353 PA',
#                'Planck 353 PI/I',
#                'Planck 217 I',
#                'Planck 217 Q',
#                'Planck 217 U',
#                'Planck 217 PI',
#                'Planck 217 PA',
#                'Planck 217 PI/I',
#                'Planck 143 I',
#                'Planck 143 Q',
#                'Planck 143 U',
#                'Planck 143 PI',
#                'Planck 143 PA',
#                'Planck 143 PI/I',
#                'Planck 100 I',
#                'Planck 100 Q',
#                'Planck 100 U',
#                'Planck 100 PI',
#                'Planck 100 PA',
#                'Planck 100 PI/I',
#                'Planck 070 I',
#                'Planck 070 Q',
#                'Planck 070 U',
#                'Planck 070 PI',
#                'Planck 070 PA',
#                'Planck 070 PI/I',
#                'Planck 044 I',
#                'Planck 044 Q',
#                'Planck 044 U',
#                'Planck 044 PI',
#                'Planck 044 PA',
#                'Planck 044 PI/I',
#                'Planck 030 I',
#                'Planck 030 Q',
#                'Planck 030 U',
#                'Planck 030 PI',
#                'Planck 030 PA',
#                'Planck 030 PI/I'],
#  'IR:UKIDSS class=': ['UKIDSS-Y',
#                       'UKIDSS-J',
#                       'UKIDSS-H',
#                       'UKIDSS-K',
#                       'UKIDSS-1-0S1'],
#  'IR:WISE class=': ['WISE 3.4', 'WISE 4.6', 'WISE 12', 'WISE 22'],
#  'IR:WMAP&COBE': ['WMAP ILC',
#                   'WMAP Ka',
#                   'WMAP K',
#                   'WMAP Q',
#                   'WMAP V',
#                   'WMAP W',
#                   'COBE DIRBE/AAM',
#                   'COBE DIRBE/ZSMA'],
#  'Optical:DSS class=': ['DSS',
#                         'DSS1 Blue',
#                         'DSS1 Red',
#                         'DSS2 Red',
#                         'DSS2 Blue',
#                         'DSS2 IR'],
#  'Optical:SDSS': ['SDSSg',
#                   'SDSSi',
#                   'SDSSr',
#                   'SDSSu',
#                   'SDSSz',
#                   'SDSSdr7g',
#                   'SDSSdr7i',
#                   'SDSSdr7r',
#                   'SDSSdr7u',
#                   'SDSSdr7z'],
#  'OtherOptical': ['TESS',
#                   'Mellinger Red',
#                   'Mellinger Green',
#                   'Mellinger Blue',
#                   'H-Alpha Comp',
#                   'SHASSA H',
#                   'SHASSA CC',
#                   'SHASSA C',
#                   'SHASSA Sm'],
#  'ROSATDiffuse class=': ['RASS Background 1',
#                          'RASS Background 2',
#                          'RASS Background 3',
#                          'RASS Background 4',
#                          'RASS Background 5',
#                          'RASS Background 6',
#                          'RASS Background 7'],
#  'ROSATw/sources class=': ['RASS-Cnt Soft',
#                            'RASS-Cnt Hard',
#                            'RASS-Cnt Broad',
#                            'PSPC 2.0 Deg-Int',
#                            'PSPC 1.0 Deg-Int',
#                            'PSPC 0.6 Deg-Int',
#                            'HRI'],
#  'Radio:GHz': ['CO',
#                'GB6 (4850MHz)',
#                'VLA FIRST (1.4 GHz)',
#                'NVSS',
#                'Stripe82VLA',
#                '1420MHz (Bonn)',
#                'HI4PI',
#                'EBHIS',
#                'nH'],
#  'Radio:GLEAM class=': ['GLEAM 72-103 MHz',
#                         'GLEAM 103-134 MHz',
#                         'GLEAM 139-170 MHz',
#                         'GLEAM 170-231 MHz'],
#  'Radio:MHz class=': ['SUMSS 843 MHz',
#                       '0408MHz',
#                       'WENSS',
#                       'TGSS ADR1',
#                       'VLSSr',
#                       '0035MHz',
#                       '0022MHz'],
#  'SoftX-ray class=': ['SwiftXRTCnt',
#                       'SwiftXRTExp',
#                       'SwiftXRTInt',
#                       'HEAO 1 A-2'],
#  'SwiftUVOT class=': ['UVOT WHITE Intensity',
#                       'UVOT V Intensity',
#                       'UVOT B Intensity',
#                       'UVOT U Intensity',
#                       'UVOT UVW1 Intensity',
#                       'UVOT UVM2 Intensity',
#                       'UVOT UVW2 Intensity'],
#  'UV': ['GALEX Near UV',
#         'GALEX Far UV',
#         'ROSAT WFC F1',
#         'ROSAT WFC F2',
#         'EUVE 83 A',
#         'EUVE 171 A',
#         'EUVE 405 A',
#         'EUVE 555 A'],
#  'X-ray:SwiftBAT': ['BAT SNR 14-195',
#                     'BAT SNR 14-20',
#                     'BAT SNR 20-24',
#                     'BAT SNR 24-35',
#                     'BAT SNR 35-50',
#                     'BAT SNR 50-75',
#                     'BAT SNR 75-100',
#                     'BAT SNR 100-150',
#                     'BAT SNR 150-195']}
# surveys:  None
# WARNING: AstropyDeprecationWarning: The truth value of a Quantity is ambiguous. In the future this will raise a ValueError. [astropy.units.quantity]
# {'Allbands:GOODS/HDF/CDF': ['GOODS: Chandra ACIS HB',
#                             'GOODS: Chandra ACIS FB',
#                             'GOODS: Chandra ACIS SB',
#                             'GOODS: VLT VIMOS U',
#                             'GOODS: VLT VIMOS R',
#                             'GOODS: HST ACS B',
#                             'GOODS: HST ACS V',
#                             'GOODS: HST ACS I',
#                             'GOODS: HST ACS Z',
#                             'Hawaii HDF U',
#                             'Hawaii HDF B',
#                             'Hawaii HDF V0201',
#                             'Hawaii HDF V0401',
#                             'Hawaii HDF R',
#                             'Hawaii HDF I',
#                             'Hawaii HDF z',
#                             'Hawaii HDF HK',
#                             'GOODS: HST NICMOS',
#                             'GOODS: VLT ISAAC J',
#                             'GOODS: VLT ISAAC H',
#                             'GOODS: VLT ISAAC Ks',
#                             'HUDF: VLT ISAAC Ks',
#                             'GOODS: Spitzer IRAC 3.6',
#                             'GOODS: Spitzer IRAC 4.5',
#                             'GOODS: Spitzer IRAC 5.8',
#                             'GOODS: Spitzer IRAC 8.0',
#                             'GOODS: Spitzer MIPS 24',
#                             'GOODS: Herschel 100',
#                             'GOODS: Herschel 160',
#                             'GOODS: Herschel 250',
#                             'GOODS: Herschel 350',
#                             'GOODS: Herschel 500',
#                             'CDFS: LESS',
#                             'GOODS: VLA North'],
#  'Allbands:HiPS': ['UltraVista-H',
#                    'UltraVista-J',
#                    'UltraVista-Ks',
#                    'UltraVista-NB118',
#                    'UltraVista-Y',
#                    'CFHTLS-W-u',
#                    'CFHTLS-W-g',
#                    'CFHTLS-W-r',
#                    'CFHTLS-W-i',
#                    'CFHTLS-W-z',
#                    'CFHTLS-D-u',
#                    'CFHTLS-D-g',
#                    'CFHTLS-D-r',
#                    'CFHTLS-D-i',
#                    'CFHTLS-D-z'],
#  'GammaRay': ['Fermi 5',
#               'Fermi 4',
#               'Fermi 3',
#               'Fermi 2',
#               'Fermi 1',
#               'EGRET (3D)',
#               'EGRET <100 MeV',
#               'EGRET >100 MeV',
#               'COMPTEL'],
#  'HardX-ray': ['INT GAL 17-35 Flux',
#                'INT GAL 17-60 Flux',
#                'INT GAL 35-80 Flux',
#                'INTEGRAL/SPI GC',
#                'GRANAT/SIGMA',
#                'RXTE Allsky 3-8keV Flux',
#                'RXTE Allsky 3-20keV Flux',
#                'RXTE Allsky 8-20keV Flux'],
#  'IR:2MASS class=': ['2MASS-J', '2MASS-H', '2MASS-K'],
#  'IR:AKARI class=': ['AKARI N60', 'AKARI WIDE-S', 'AKARI WIDE-L', 'AKARI N160'],
#  'IR:IRAS': ['IRIS  12',
#              'IRIS  25',
#              'IRIS  60',
#              'IRIS 100',
#              'SFD100m',
#              'SFD Dust Map',
#              'IRAS  12 micron',
#              'IRAS  25 micron',
#              'IRAS  60 micron',
#              'IRAS 100 micron'],
#  'IR:Planck': ['Planck 857 I',
#                'Planck 545 I',
#                'Planck 353 I',
#                'Planck 353 Q',
#                'Planck 353 U',
#                'Planck 353 PI',
#                'Planck 353 PA',
#                'Planck 353 PI/I',
#                'Planck 217 I',
#                'Planck 217 Q',
#                'Planck 217 U',
#                'Planck 217 PI',
#                'Planck 217 PA',
#                'Planck 217 PI/I',
#                'Planck 143 I',
#                'Planck 143 Q',
#                'Planck 143 U',
#                'Planck 143 PI',
#                'Planck 143 PA',
#                'Planck 143 PI/I',
#                'Planck 100 I',
#                'Planck 100 Q',
#                'Planck 100 U',
#                'Planck 100 PI',
#                'Planck 100 PA',
#                'Planck 100 PI/I',
#                'Planck 070 I',
#                'Planck 070 Q',
#                'Planck 070 U',
#                'Planck 070 PI',
#                'Planck 070 PA',
#                'Planck 070 PI/I',
#                'Planck 044 I',
#                'Planck 044 Q',
#                'Planck 044 U',
#                'Planck 044 PI',
#                'Planck 044 PA',
#                'Planck 044 PI/I',
#                'Planck 030 I',
#                'Planck 030 Q',
#                'Planck 030 U',
#                'Planck 030 PI',
#                'Planck 030 PA',
#                'Planck 030 PI/I'],
#  'IR:UKIDSS class=': ['UKIDSS-Y',
#                       'UKIDSS-J',
#                       'UKIDSS-H',
#                       'UKIDSS-K',
#                       'UKIDSS-1-0S1'],
#  'IR:WISE class=': ['WISE 3.4', 'WISE 4.6', 'WISE 12', 'WISE 22'],
#  'IR:WMAP&COBE': ['WMAP ILC',
#                   'WMAP Ka',
#                   'WMAP K',
#                   'WMAP Q',
#                   'WMAP V',
#                   'WMAP W',
#                   'COBE DIRBE/AAM',
#                   'COBE DIRBE/ZSMA'],
#  'Optical:DSS class=': ['DSS',
#                         'DSS1 Blue',
#                         'DSS1 Red',
#                         'DSS2 Red',
#                         'DSS2 Blue',
#                         'DSS2 IR'],
#  'Optical:SDSS': ['SDSSg',
#                   'SDSSi',
#                   'SDSSr',
#                   'SDSSu',
#                   'SDSSz',
#                   'SDSSdr7g',
#                   'SDSSdr7i',
#                   'SDSSdr7r',
#                   'SDSSdr7u',
#                   'SDSSdr7z'],
#  'OtherOptical': ['TESS',
#                   'Mellinger Red',
#                   'Mellinger Green',
#                   'Mellinger Blue',
#                   'H-Alpha Comp',
#                   'SHASSA H',
#                   'SHASSA CC',
#                   'SHASSA C',
#                   'SHASSA Sm'],
#  'ROSATDiffuse class=': ['RASS Background 1',
#                          'RASS Background 2',
#                          'RASS Background 3',
#                          'RASS Background 4',
#                          'RASS Background 5',
#                          'RASS Background 6',
#                          'RASS Background 7'],
#  'ROSATw/sources class=': ['RASS-Cnt Soft',
#                            'RASS-Cnt Hard',
#                            'RASS-Cnt Broad',
#                            'PSPC 2.0 Deg-Int',
#                            'PSPC 1.0 Deg-Int',
#                            'PSPC 0.6 Deg-Int',
#                            'HRI'],
#  'Radio:GHz': ['CO',
#                'GB6 (4850MHz)',
#                'VLA FIRST (1.4 GHz)',
#                'NVSS',
#                'Stripe82VLA',
#                '1420MHz (Bonn)',
#                'HI4PI',
#                'EBHIS',
#                'nH'],
#  'Radio:GLEAM class=': ['GLEAM 72-103 MHz',
#                         'GLEAM 103-134 MHz',
#                         'GLEAM 139-170 MHz',
#                         'GLEAM 170-231 MHz'],
#  'Radio:MHz class=': ['SUMSS 843 MHz',
#                       '0408MHz',
#                       'WENSS',
#                       'TGSS ADR1',
#                       'VLSSr',
#                       '0035MHz',
#                       '0022MHz'],
#  'SoftX-ray class=': ['SwiftXRTCnt',
#                       'SwiftXRTExp',
#                       'SwiftXRTInt',
#                       'HEAO 1 A-2'],
#  'SwiftUVOT class=': ['UVOT WHITE Intensity',
#                       'UVOT V Intensity',
#                       'UVOT B Intensity',
#                       'UVOT U Intensity',
#                       'UVOT UVW1 Intensity',
#                       'UVOT UVM2 Intensity',
#                       'UVOT UVW2 Intensity'],
#  'UV': ['GALEX Near UV',
#         'GALEX Far UV',
#         'ROSAT WFC F1',
#         'ROSAT WFC F2',
#         'EUVE 83 A',
#         'EUVE 171 A',
#         'EUVE 405 A',
#         'EUVE 555 A'],
#  'X-ray:SwiftBAT': ['BAT SNR 14-195',
#                     'BAT SNR 14-20',
#                     'BAT SNR 20-24',
#                     'BAT SNR 24-35',
#                     'BAT SNR 35-50',
#                     'BAT SNR 50-75',
#                     'BAT SNR 75-100',
#                     'BAT SNR 100-150',
#                     'BAT SNR 150-195']}
# surveys:  None
# WARNING: AstropyDeprecationWarning: The truth value of a Quantity is ambiguous. In the future this will raise a ValueError. [astropy.units.quantity]
# {'Allbands:GOODS/HDF/CDF': ['GOODS: Chandra ACIS HB',
#                             'GOODS: Chandra ACIS FB',
#                             'GOODS: Chandra ACIS SB',
#                             'GOODS: VLT VIMOS U',
#                             'GOODS: VLT VIMOS R',
#                             'GOODS: HST ACS B',
#                             'GOODS: HST ACS V',
#                             'GOODS: HST ACS I',
#                             'GOODS: HST ACS Z',
#                             'Hawaii HDF U',
#                             'Hawaii HDF B',
#                             'Hawaii HDF V0201',
#                             'Hawaii HDF V0401',
#                             'Hawaii HDF R',
#                             'Hawaii HDF I',
#                             'Hawaii HDF z',
#                             'Hawaii HDF HK',
#                             'GOODS: HST NICMOS',
#                             'GOODS: VLT ISAAC J',
#                             'GOODS: VLT ISAAC H',
#                             'GOODS: VLT ISAAC Ks',
#                             'HUDF: VLT ISAAC Ks',
#                             'GOODS: Spitzer IRAC 3.6',
#                             'GOODS: Spitzer IRAC 4.5',
#                             'GOODS: Spitzer IRAC 5.8',
#                             'GOODS: Spitzer IRAC 8.0',
#                             'GOODS: Spitzer MIPS 24',
#                             'GOODS: Herschel 100',
#                             'GOODS: Herschel 160',
#                             'GOODS: Herschel 250',
#                             'GOODS: Herschel 350',
#                             'GOODS: Herschel 500',
#                             'CDFS: LESS',
#                             'GOODS: VLA North'],
#  'Allbands:HiPS': ['UltraVista-H',
#                    'UltraVista-J',
#                    'UltraVista-Ks',
#                    'UltraVista-NB118',
#                    'UltraVista-Y',
#                    'CFHTLS-W-u',
#                    'CFHTLS-W-g',
#                    'CFHTLS-W-r',
#                    'CFHTLS-W-i',
#                    'CFHTLS-W-z',
#                    'CFHTLS-D-u',
#                    'CFHTLS-D-g',
#                    'CFHTLS-D-r',
#                    'CFHTLS-D-i',
#                    'CFHTLS-D-z'],
#  'GammaRay': ['Fermi 5',
#               'Fermi 4',
#               'Fermi 3',
#               'Fermi 2',
#               'Fermi 1',
#               'EGRET (3D)',
#               'EGRET <100 MeV',
#               'EGRET >100 MeV',
#               'COMPTEL'],
#  'HardX-ray': ['INT GAL 17-35 Flux',
#                'INT GAL 17-60 Flux',
#                'INT GAL 35-80 Flux',
#                'INTEGRAL/SPI GC',
#                'GRANAT/SIGMA',
#                'RXTE Allsky 3-8keV Flux',
#                'RXTE Allsky 3-20keV Flux',
#                'RXTE Allsky 8-20keV Flux'],
#  'IR:2MASS class=': ['2MASS-J', '2MASS-H', '2MASS-K'],
#  'IR:AKARI class=': ['AKARI N60', 'AKARI WIDE-S', 'AKARI WIDE-L', 'AKARI N160'],
#  'IR:IRAS': ['IRIS  12',
#              'IRIS  25',
#              'IRIS  60',
#              'IRIS 100',
#              'SFD100m',
#              'SFD Dust Map',
#              'IRAS  12 micron',
#              'IRAS  25 micron',
#              'IRAS  60 micron',
#              'IRAS 100 micron'],
#  'IR:Planck': ['Planck 857 I',
#                'Planck 545 I',
#                'Planck 353 I',
#                'Planck 353 Q',
#                'Planck 353 U',
#                'Planck 353 PI',
#                'Planck 353 PA',
#                'Planck 353 PI/I',
#                'Planck 217 I',
#                'Planck 217 Q',
#                'Planck 217 U',
#                'Planck 217 PI',
#                'Planck 217 PA',
#                'Planck 217 PI/I',
#                'Planck 143 I',
#                'Planck 143 Q',
#                'Planck 143 U',
#                'Planck 143 PI',
#                'Planck 143 PA',
#                'Planck 143 PI/I',
#                'Planck 100 I',
#                'Planck 100 Q',
#                'Planck 100 U',
#                'Planck 100 PI',
#                'Planck 100 PA',
#                'Planck 100 PI/I',
#                'Planck 070 I',
#                'Planck 070 Q',
#                'Planck 070 U',
#                'Planck 070 PI',
#                'Planck 070 PA',
#                'Planck 070 PI/I',
#                'Planck 044 I',
#                'Planck 044 Q',
#                'Planck 044 U',
#                'Planck 044 PI',
#                'Planck 044 PA',
#                'Planck 044 PI/I',
#                'Planck 030 I',
#                'Planck 030 Q',
#                'Planck 030 U',
#                'Planck 030 PI',
#                'Planck 030 PA',
#                'Planck 030 PI/I'],
#  'IR:UKIDSS class=': ['UKIDSS-Y',
#                       'UKIDSS-J',
#                       'UKIDSS-H',
#                       'UKIDSS-K',
#                       'UKIDSS-1-0S1'],
#  'IR:WISE class=': ['WISE 3.4', 'WISE 4.6', 'WISE 12', 'WISE 22'],
#  'IR:WMAP&COBE': ['WMAP ILC',
#                   'WMAP Ka',
#                   'WMAP K',
#                   'WMAP Q',
#                   'WMAP V',
#                   'WMAP W',
#                   'COBE DIRBE/AAM',
#                   'COBE DIRBE/ZSMA'],
#  'Optical:DSS class=': ['DSS',
#                         'DSS1 Blue',
#                         'DSS1 Red',
#                         'DSS2 Red',
#                         'DSS2 Blue',
#                         'DSS2 IR'],
#  'Optical:SDSS': ['SDSSg',
#                   'SDSSi',
#                   'SDSSr',
#                   'SDSSu',
#                   'SDSSz',
#                   'SDSSdr7g',
#                   'SDSSdr7i',
#                   'SDSSdr7r',
#                   'SDSSdr7u',
#                   'SDSSdr7z'],
#  'OtherOptical': ['TESS',
#                   'Mellinger Red',
#                   'Mellinger Green',
#                   'Mellinger Blue',
#                   'H-Alpha Comp',
#                   'SHASSA H',
#                   'SHASSA CC',
#                   'SHASSA C',
#                   'SHASSA Sm'],
#  'ROSATDiffuse class=': ['RASS Background 1',
#                          'RASS Background 2',
#                          'RASS Background 3',
#                          'RASS Background 4',
#                          'RASS Background 5',
#                          'RASS Background 6',
#                          'RASS Background 7'],
#  'ROSATw/sources class=': ['RASS-Cnt Soft',
#                            'RASS-Cnt Hard',
#                            'RASS-Cnt Broad',
#                            'PSPC 2.0 Deg-Int',
#                            'PSPC 1.0 Deg-Int',
#                            'PSPC 0.6 Deg-Int',
#                            'HRI'],
#  'Radio:GHz': ['CO',
#                'GB6 (4850MHz)',
#                'VLA FIRST (1.4 GHz)',
#                'NVSS',
#                'Stripe82VLA',
#                '1420MHz (Bonn)',
#                'HI4PI',
#                'EBHIS',
#                'nH'],
#  'Radio:GLEAM class=': ['GLEAM 72-103 MHz',
#                         'GLEAM 103-134 MHz',
#                         'GLEAM 139-170 MHz',
#                         'GLEAM 170-231 MHz'],
#  'Radio:MHz class=': ['SUMSS 843 MHz',
#                       '0408MHz',
#                       'WENSS',
#                       'TGSS ADR1',
#                       'VLSSr',
#                       '0035MHz',
#                       '0022MHz'],
#  'SoftX-ray class=': ['SwiftXRTCnt',
#                       'SwiftXRTExp',
#                       'SwiftXRTInt',
#                       'HEAO 1 A-2'],
#  'SwiftUVOT class=': ['UVOT WHITE Intensity',
#                       'UVOT V Intensity',
#                       'UVOT B Intensity',
#                       'UVOT U Intensity',
#                       'UVOT UVW1 Intensity',
#                       'UVOT UVM2 Intensity',
#                       'UVOT UVW2 Intensity'],
#  'UV': ['GALEX Near UV',
#         'GALEX Far UV',
#         'ROSAT WFC F1',
#         'ROSAT WFC F2',
#         'EUVE 83 A',
#         'EUVE 171 A',
#         'EUVE 405 A',
#         'EUVE 555 A'],
#  'X-ray:SwiftBAT': ['BAT SNR 14-195',
#                     'BAT SNR 14-20',
#                     'BAT SNR 20-24',
#                     'BAT SNR 24-35',
#                     'BAT SNR 35-50',
#                     'BAT SNR 50-75',
#                     'BAT SNR 75-100',
#                     'BAT SNR 100-150',
#                     'BAT SNR 150-195']}
# surveys:  None
# WARNING: AstropyDeprecationWarning: The truth value of a Quantity is ambiguous. In the future this will raise a ValueError. [astropy.units.quantity]
# {'Allbands:GOODS/HDF/CDF': ['GOODS: Chandra ACIS HB',
#                             'GOODS: Chandra ACIS FB',
#                             'GOODS: Chandra ACIS SB',
#                             'GOODS: VLT VIMOS U',
#                             'GOODS: VLT VIMOS R',
#                             'GOODS: HST ACS B',
#                             'GOODS: HST ACS V',
#                             'GOODS: HST ACS I',
#                             'GOODS: HST ACS Z',
#                             'Hawaii HDF U',
#                             'Hawaii HDF B',
#                             'Hawaii HDF V0201',
#                             'Hawaii HDF V0401',
#                             'Hawaii HDF R',
#                             'Hawaii HDF I',
#                             'Hawaii HDF z',
#                             'Hawaii HDF HK',
#                             'GOODS: HST NICMOS',
#                             'GOODS: VLT ISAAC J',
#                             'GOODS: VLT ISAAC H',
#                             'GOODS: VLT ISAAC Ks',
#                             'HUDF: VLT ISAAC Ks',
#                             'GOODS: Spitzer IRAC 3.6',
#                             'GOODS: Spitzer IRAC 4.5',
#                             'GOODS: Spitzer IRAC 5.8',
#                             'GOODS: Spitzer IRAC 8.0',
#                             'GOODS: Spitzer MIPS 24',
#                             'GOODS: Herschel 100',
#                             'GOODS: Herschel 160',
#                             'GOODS: Herschel 250',
#                             'GOODS: Herschel 350',
#                             'GOODS: Herschel 500',
#                             'CDFS: LESS',
#                             'GOODS: VLA North'],
#  'Allbands:HiPS': ['UltraVista-H',
#                    'UltraVista-J',
#                    'UltraVista-Ks',
#                    'UltraVista-NB118',
#                    'UltraVista-Y',
#                    'CFHTLS-W-u',
#                    'CFHTLS-W-g',
#                    'CFHTLS-W-r',
#                    'CFHTLS-W-i',
#                    'CFHTLS-W-z',
#                    'CFHTLS-D-u',
#                    'CFHTLS-D-g',
#                    'CFHTLS-D-r',
#                    'CFHTLS-D-i',
#                    'CFHTLS-D-z'],
#  'GammaRay': ['Fermi 5',
#               'Fermi 4',
#               'Fermi 3',
#               'Fermi 2',
#               'Fermi 1',
#               'EGRET (3D)',
#               'EGRET <100 MeV',
#               'EGRET >100 MeV',
#               'COMPTEL'],
#  'HardX-ray': ['INT GAL 17-35 Flux',
#                'INT GAL 17-60 Flux',
#                'INT GAL 35-80 Flux',
#                'INTEGRAL/SPI GC',
#                'GRANAT/SIGMA',
#                'RXTE Allsky 3-8keV Flux',
#                'RXTE Allsky 3-20keV Flux',
#                'RXTE Allsky 8-20keV Flux'],
#  'IR:2MASS class=': ['2MASS-J', '2MASS-H', '2MASS-K'],
#  'IR:AKARI class=': ['AKARI N60', 'AKARI WIDE-S', 'AKARI WIDE-L', 'AKARI N160'],
#  'IR:IRAS': ['IRIS  12',
#              'IRIS  25',
#              'IRIS  60',
#              'IRIS 100',
#              'SFD100m',
#              'SFD Dust Map',
#              'IRAS  12 micron',
#              'IRAS  25 micron',
#              'IRAS  60 micron',
#              'IRAS 100 micron'],
#  'IR:Planck': ['Planck 857 I',
#                'Planck 545 I',
#                'Planck 353 I',
#                'Planck 353 Q',
#                'Planck 353 U',
#                'Planck 353 PI',
#                'Planck 353 PA',
#                'Planck 353 PI/I',
#                'Planck 217 I',
#                'Planck 217 Q',
#                'Planck 217 U',
#                'Planck 217 PI',
#                'Planck 217 PA',
#                'Planck 217 PI/I',
#                'Planck 143 I',
#                'Planck 143 Q',
#                'Planck 143 U',
#                'Planck 143 PI',
#                'Planck 143 PA',
#                'Planck 143 PI/I',
#                'Planck 100 I',
#                'Planck 100 Q',
#                'Planck 100 U',
#                'Planck 100 PI',
#                'Planck 100 PA',
#                'Planck 100 PI/I',
#                'Planck 070 I',
#                'Planck 070 Q',
#                'Planck 070 U',
#                'Planck 070 PI',
#                'Planck 070 PA',
#                'Planck 070 PI/I',
#                'Planck 044 I',
#                'Planck 044 Q',
#                'Planck 044 U',
#                'Planck 044 PI',
#                'Planck 044 PA',
#                'Planck 044 PI/I',
#                'Planck 030 I',
#                'Planck 030 Q',
#                'Planck 030 U',
#                'Planck 030 PI',
#                'Planck 030 PA',
#                'Planck 030 PI/I'],
#  'IR:UKIDSS class=': ['UKIDSS-Y',
#                       'UKIDSS-J',
#                       'UKIDSS-H',
#                       'UKIDSS-K',
#                       'UKIDSS-1-0S1'],
#  'IR:WISE class=': ['WISE 3.4', 'WISE 4.6', 'WISE 12', 'WISE 22'],
#  'IR:WMAP&COBE': ['WMAP ILC',
#                   'WMAP Ka',
#                   'WMAP K',
#                   'WMAP Q',
#                   'WMAP V',
#                   'WMAP W',
#                   'COBE DIRBE/AAM',
#                   'COBE DIRBE/ZSMA'],
#  'Optical:DSS class=': ['DSS',
#                         'DSS1 Blue',
#                         'DSS1 Red',
#                         'DSS2 Red',
#                         'DSS2 Blue',
#                         'DSS2 IR'],
#  'Optical:SDSS': ['SDSSg',
#                   'SDSSi',
#                   'SDSSr',
#                   'SDSSu',
#                   'SDSSz',
#                   'SDSSdr7g',
#                   'SDSSdr7i',
#                   'SDSSdr7r',
#                   'SDSSdr7u',
#                   'SDSSdr7z'],
#  'OtherOptical': ['TESS',
#                   'Mellinger Red',
#                   'Mellinger Green',
#                   'Mellinger Blue',
#                   'H-Alpha Comp',
#                   'SHASSA H',
#                   'SHASSA CC',
#                   'SHASSA C',
#                   'SHASSA Sm'],
#  'ROSATDiffuse class=': ['RASS Background 1',
#                          'RASS Background 2',
#                          'RASS Background 3',
#                          'RASS Background 4',
#                          'RASS Background 5',
#                          'RASS Background 6',
#                          'RASS Background 7'],
#  'ROSATw/sources class=': ['RASS-Cnt Soft',
#                            'RASS-Cnt Hard',
#                            'RASS-Cnt Broad',
#                            'PSPC 2.0 Deg-Int',
#                            'PSPC 1.0 Deg-Int',
#                            'PSPC 0.6 Deg-Int',
#                            'HRI'],
#  'Radio:GHz': ['CO',
#                'GB6 (4850MHz)',
#                'VLA FIRST (1.4 GHz)',
#                'NVSS',
#                'Stripe82VLA',
#                '1420MHz (Bonn)',
#                'HI4PI',
#                'EBHIS',
#                'nH'],
#  'Radio:GLEAM class=': ['GLEAM 72-103 MHz',
#                         'GLEAM 103-134 MHz',
#                         'GLEAM 139-170 MHz',
#                         'GLEAM 170-231 MHz'],
#  'Radio:MHz class=': ['SUMSS 843 MHz',
#                       '0408MHz',
#                       'WENSS',
#                       'TGSS ADR1',
#                       'VLSSr',
#                       '0035MHz',
#                       '0022MHz'],
#  'SoftX-ray class=': ['SwiftXRTCnt',
#                       'SwiftXRTExp',
#                       'SwiftXRTInt',
#                       'HEAO 1 A-2'],
#  'SwiftUVOT class=': ['UVOT WHITE Intensity',
#                       'UVOT V Intensity',
#                       'UVOT B Intensity',
#                       'UVOT U Intensity',
#                       'UVOT UVW1 Intensity',
#                       'UVOT UVM2 Intensity',
#                       'UVOT UVW2 Intensity'],
#  'UV': ['GALEX Near UV',
#         'GALEX Far UV',
#         'ROSAT WFC F1',
#         'ROSAT WFC F2',
#         'EUVE 83 A',
#         'EUVE 171 A',
#         'EUVE 405 A',
#         'EUVE 555 A'],
#  'X-ray:SwiftBAT': ['BAT SNR 14-195',
#                     'BAT SNR 14-20',
#                     'BAT SNR 20-24',
#                     'BAT SNR 24-35',
#                     'BAT SNR 35-50',
#                     'BAT SNR 50-75',
#                     'BAT SNR 75-100',
#                     'BAT SNR 100-150',
#                     'BAT SNR 150-195']}
# surveys:  None
# WARNING: AstropyDeprecationWarning: The truth value of a Quantity is ambiguous. In the future this will raise a ValueError. [astropy.units.quantity]
# {'Allbands:GOODS/HDF/CDF': ['GOODS: Chandra ACIS HB',
#                             'GOODS: Chandra ACIS FB',
#                             'GOODS: Chandra ACIS SB',
#                             'GOODS: VLT VIMOS U',
#                             'GOODS: VLT VIMOS R',
#                             'GOODS: HST ACS B',
#                             'GOODS: HST ACS V',
#                             'GOODS: HST ACS I',
#                             'GOODS: HST ACS Z',
#                             'Hawaii HDF U',
#                             'Hawaii HDF B',
#                             'Hawaii HDF V0201',
#                             'Hawaii HDF V0401',
#                             'Hawaii HDF R',
#                             'Hawaii HDF I',
#                             'Hawaii HDF z',
#                             'Hawaii HDF HK',
#                             'GOODS: HST NICMOS',
#                             'GOODS: VLT ISAAC J',
#                             'GOODS: VLT ISAAC H',
#                             'GOODS: VLT ISAAC Ks',
#                             'HUDF: VLT ISAAC Ks',
#                             'GOODS: Spitzer IRAC 3.6',
#                             'GOODS: Spitzer IRAC 4.5',
#                             'GOODS: Spitzer IRAC 5.8',
#                             'GOODS: Spitzer IRAC 8.0',
#                             'GOODS: Spitzer MIPS 24',
#                             'GOODS: Herschel 100',
#                             'GOODS: Herschel 160',
#                             'GOODS: Herschel 250',
#                             'GOODS: Herschel 350',
#                             'GOODS: Herschel 500',
#                             'CDFS: LESS',
#                             'GOODS: VLA North'],
#  'Allbands:HiPS': ['UltraVista-H',
#                    'UltraVista-J',
#                    'UltraVista-Ks',
#                    'UltraVista-NB118',
#                    'UltraVista-Y',
#                    'CFHTLS-W-u',
#                    'CFHTLS-W-g',
#                    'CFHTLS-W-r',
#                    'CFHTLS-W-i',
#                    'CFHTLS-W-z',
#                    'CFHTLS-D-u',
#                    'CFHTLS-D-g',
#                    'CFHTLS-D-r',
#                    'CFHTLS-D-i',
#                    'CFHTLS-D-z'],
#  'GammaRay': ['Fermi 5',
#               'Fermi 4',
#               'Fermi 3',
#               'Fermi 2',
#               'Fermi 1',
#               'EGRET (3D)',
#               'EGRET <100 MeV',
#               'EGRET >100 MeV',
#               'COMPTEL'],
#  'HardX-ray': ['INT GAL 17-35 Flux',
#                'INT GAL 17-60 Flux',
#                'INT GAL 35-80 Flux',
#                'INTEGRAL/SPI GC',
#                'GRANAT/SIGMA',
#                'RXTE Allsky 3-8keV Flux',
#                'RXTE Allsky 3-20keV Flux',
#                'RXTE Allsky 8-20keV Flux'],
#  'IR:2MASS class=': ['2MASS-J', '2MASS-H', '2MASS-K'],
#  'IR:AKARI class=': ['AKARI N60', 'AKARI WIDE-S', 'AKARI WIDE-L', 'AKARI N160'],
#  'IR:IRAS': ['IRIS  12',
#              'IRIS  25',
#              'IRIS  60',
#              'IRIS 100',
#              'SFD100m',
#              'SFD Dust Map',
#              'IRAS  12 micron',
#              'IRAS  25 micron',
#              'IRAS  60 micron',
#              'IRAS 100 micron'],
#  'IR:Planck': ['Planck 857 I',
#                'Planck 545 I',
#                'Planck 353 I',
#                'Planck 353 Q',
#                'Planck 353 U',
#                'Planck 353 PI',
#                'Planck 353 PA',
#                'Planck 353 PI/I',
#                'Planck 217 I',
#                'Planck 217 Q',
#                'Planck 217 U',
#                'Planck 217 PI',
#                'Planck 217 PA',
#                'Planck 217 PI/I',
#                'Planck 143 I',
#                'Planck 143 Q',
#                'Planck 143 U',
#                'Planck 143 PI',
#                'Planck 143 PA',
#                'Planck 143 PI/I',
#                'Planck 100 I',
#                'Planck 100 Q',
#                'Planck 100 U',
#                'Planck 100 PI',
#                'Planck 100 PA',
#                'Planck 100 PI/I',
#                'Planck 070 I',
#                'Planck 070 Q',
#                'Planck 070 U',
#                'Planck 070 PI',
#                'Planck 070 PA',
#                'Planck 070 PI/I',
#                'Planck 044 I',
#                'Planck 044 Q',
#                'Planck 044 U',
#                'Planck 044 PI',
#                'Planck 044 PA',
#                'Planck 044 PI/I',
#                'Planck 030 I',
#                'Planck 030 Q',
#                'Planck 030 U',
#                'Planck 030 PI',
#                'Planck 030 PA',
#                'Planck 030 PI/I'],
#  'IR:UKIDSS class=': ['UKIDSS-Y',
#                       'UKIDSS-J',
#                       'UKIDSS-H',
#                       'UKIDSS-K',
#                       'UKIDSS-1-0S1'],
#  'IR:WISE class=': ['WISE 3.4', 'WISE 4.6', 'WISE 12', 'WISE 22'],
#  'IR:WMAP&COBE': ['WMAP ILC',
#                   'WMAP Ka',
#                   'WMAP K',
#                   'WMAP Q',
#                   'WMAP V',
#                   'WMAP W',
#                   'COBE DIRBE/AAM',
#                   'COBE DIRBE/ZSMA'],
#  'Optical:DSS class=': ['DSS',
#                         'DSS1 Blue',
#                         'DSS1 Red',
#                         'DSS2 Red',
#                         'DSS2 Blue',
#                         'DSS2 IR'],
#  'Optical:SDSS': ['SDSSg',
#                   'SDSSi',
#                   'SDSSr',
#                   'SDSSu',
#                   'SDSSz',
#                   'SDSSdr7g',
#                   'SDSSdr7i',
#                   'SDSSdr7r',
#                   'SDSSdr7u',
#                   'SDSSdr7z'],
#  'OtherOptical': ['TESS',
#                   'Mellinger Red',
#                   'Mellinger Green',
#                   'Mellinger Blue',
#                   'H-Alpha Comp',
#                   'SHASSA H',
#                   'SHASSA CC',
#                   'SHASSA C',
#                   'SHASSA Sm'],
#  'ROSATDiffuse class=': ['RASS Background 1',
#                          'RASS Background 2',
#                          'RASS Background 3',
#                          'RASS Background 4',
#                          'RASS Background 5',
#                          'RASS Background 6',
#                          'RASS Background 7'],
#  'ROSATw/sources class=': ['RASS-Cnt Soft',
#                            'RASS-Cnt Hard',
#                            'RASS-Cnt Broad',
#                            'PSPC 2.0 Deg-Int',
#                            'PSPC 1.0 Deg-Int',
#                            'PSPC 0.6 Deg-Int',
#                            'HRI'],
#  'Radio:GHz': ['CO',
#                'GB6 (4850MHz)',
#                'VLA FIRST (1.4 GHz)',
#                'NVSS',
# ...
#                             'GOODS: Herschel 350',
#                             'GOODS: Herschel 500',
#                             'CDFS: LESS',
#                             'GOODS: VLA North'],
#  'Allbands:HiPS': ['UltraVista-H',
#                    'UltraVista-J',
#                    'UltraVista-Ks',
#                    'UltraVista-NB118',
#                    'UltraVista-Y',
#                    'CFHTLS-W-u',
#                    'CFHTLS-W-g',
#                    'CFHTLS-W-r',
#                    'CFHTLS-W-i',
#                    'CFHTLS-W-z',
#                    'CFHTLS-D-u',
#                    'CFHTLS-D-g',
#                    'CFHTLS-D-r',
#                    'CFHTLS-D-i',
#                    'CFHTLS-D-z'],
#  'GammaRay': ['Fermi 5',
#               'Fermi 4',
#               'Fermi 3',
#               'Fermi 2',
#               'Fermi 1',
#               'EGRET (3D)',
#               'EGRET <100 MeV',
#               'EGRET >100 MeV',
#               'COMPTEL'],
#  'HardX-ray': ['INT GAL 17-35 Flux',
#                'INT GAL 17-60 Flux',
#                'INT GAL 35-80 Flux',
#                'INTEGRAL/SPI GC',
#                'GRANAT/SIGMA',
#                'RXTE Allsky 3-8keV Flux',
#                'RXTE Allsky 3-20keV Flux',
#                'RXTE Allsky 8-20keV Flux'],
#  'IR:2MASS class=': ['2MASS-J', '2MASS-H', '2MASS-K'],
#  'IR:AKARI class=': ['AKARI N60', 'AKARI WIDE-S', 'AKARI WIDE-L', 'AKARI N160'],
#  'IR:IRAS': ['IRIS  12',
#              'IRIS  25',
#              'IRIS  60',
#              'IRIS 100',
#              'SFD100m',
#              'SFD Dust Map',
#              'IRAS  12 micron',
#              'IRAS  25 micron',
#              'IRAS  60 micron',
#              'IRAS 100 micron'],
#  'IR:Planck': ['Planck 857 I',
#                'Planck 545 I',
#                'Planck 353 I',
#                'Planck 353 Q',
#                'Planck 353 U',
#                'Planck 353 PI',
#                'Planck 353 PA',
#                'Planck 353 PI/I',
#                'Planck 217 I',
#                'Planck 217 Q',
#                'Planck 217 U',
#                'Planck 217 PI',
#                'Planck 217 PA',
#                'Planck 217 PI/I',
#                'Planck 143 I',
#                'Planck 143 Q',
#                'Planck 143 U',
#                'Planck 143 PI',
#                'Planck 143 PA',
#                'Planck 143 PI/I',
#                'Planck 100 I',
#                'Planck 100 Q',
#                'Planck 100 U',
#                'Planck 100 PI',
#                'Planck 100 PA',
#                'Planck 100 PI/I',
#                'Planck 070 I',
#                'Planck 070 Q',
#                'Planck 070 U',
#                'Planck 070 PI',
#                'Planck 070 PA',
#                'Planck 070 PI/I',
#                'Planck 044 I',
#                'Planck 044 Q',
#                'Planck 044 U',
#                'Planck 044 PI',
#                'Planck 044 PA',
#                'Planck 044 PI/I',
#                'Planck 030 I',
#                'Planck 030 Q',
#                'Planck 030 U',
#                'Planck 030 PI',
#                'Planck 030 PA',
#                'Planck 030 PI/I'],
#  'IR:UKIDSS class=': ['UKIDSS-Y',
#                       'UKIDSS-J',
#                       'UKIDSS-H',
#                       'UKIDSS-K',
#                       'UKIDSS-1-0S1'],
#  'IR:WISE class=': ['WISE 3.4', 'WISE 4.6', 'WISE 12', 'WISE 22'],
#  'IR:WMAP&COBE': ['WMAP ILC',
#                   'WMAP Ka',
#                   'WMAP K',
#                   'WMAP Q',
#                   'WMAP V',
#                   'WMAP W',
#                   'COBE DIRBE/AAM',
#                   'COBE DIRBE/ZSMA'],
#  'Optical:DSS class=': ['DSS',
#                         'DSS1 Blue',
#                         'DSS1 Red',
#                         'DSS2 Red',
#                         'DSS2 Blue',
#                         'DSS2 IR'],
#  'Optical:SDSS': ['SDSSg',
#                   'SDSSi',
#                   'SDSSr',
#                   'SDSSu',
#                   'SDSSz',
#                   'SDSSdr7g',
#                   'SDSSdr7i',
#                   'SDSSdr7r',
#                   'SDSSdr7u',
#                   'SDSSdr7z'],
#  'OtherOptical': ['TESS',
#                   'Mellinger Red',
#                   'Mellinger Green',
#                   'Mellinger Blue',
#                   'H-Alpha Comp',
#                   'SHASSA H',
#                   'SHASSA CC',
#                   'SHASSA C',
#                   'SHASSA Sm'],
#  'ROSATDiffuse class=': ['RASS Background 1',
#                          'RASS Background 2',
#                          'RASS Background 3',
#                          'RASS Background 4',
#                          'RASS Background 5',
#                          'RASS Background 6',
#                          'RASS Background 7'],
#  'ROSATw/sources class=': ['RASS-Cnt Soft',
#                            'RASS-Cnt Hard',
#                            'RASS-Cnt Broad',
#                            'PSPC 2.0 Deg-Int',
#                            'PSPC 1.0 Deg-Int',
#                            'PSPC 0.6 Deg-Int',
#                            'HRI'],
#  'Radio:GHz': ['CO',
#                'GB6 (4850MHz)',
#                'VLA FIRST (1.4 GHz)',
#                'NVSS',
#                'Stripe82VLA',
#                '1420MHz (Bonn)',
#                'HI4PI',
#                'EBHIS',
#                'nH'],
#  'Radio:GLEAM class=': ['GLEAM 72-103 MHz',
#                         'GLEAM 103-134 MHz',
#                         'GLEAM 139-170 MHz',
#                         'GLEAM 170-231 MHz'],
#  'Radio:MHz class=': ['SUMSS 843 MHz',
#                       '0408MHz',
#                       'WENSS',
#                       'TGSS ADR1',
#                       'VLSSr',
#                       '0035MHz',
#                       '0022MHz'],
#  'SoftX-ray class=': ['SwiftXRTCnt',
#                       'SwiftXRTExp',
#                       'SwiftXRTInt',
#                       'HEAO 1 A-2'],
#  'SwiftUVOT class=': ['UVOT WHITE Intensity',
#                       'UVOT V Intensity',
#                       'UVOT B Intensity',
#                       'UVOT U Intensity',
#                       'UVOT UVW1 Intensity',
#                       'UVOT UVM2 Intensity',
#                       'UVOT UVW2 Intensity'],
#  'UV': ['GALEX Near UV',
#         'GALEX Far UV',
#         'ROSAT WFC F1',
#         'ROSAT WFC F2',
#         'EUVE 83 A',
#         'EUVE 171 A',
#         'EUVE 405 A',
#         'EUVE 555 A'],
#  'X-ray:SwiftBAT': ['BAT SNR 14-195',
#                     'BAT SNR 14-20',
#                     'BAT SNR 20-24',
#                     'BAT SNR 24-35',
#                     'BAT SNR 35-50',
#                     'BAT SNR 50-75',
#                     'BAT SNR 75-100',
#                     'BAT SNR 100-150',
#                     'BAT SNR 150-195']}
# surveys:  None
# WARNING: AstropyDeprecationWarning: The truth value of a Quantity is ambiguous. In the future this will raise a ValueError. [astropy.units.quantity]
# {'Allbands:GOODS/HDF/CDF': ['GOODS: Chandra ACIS HB',
#                             'GOODS: Chandra ACIS FB',
#                             'GOODS: Chandra ACIS SB',
#                             'GOODS: VLT VIMOS U',
#                             'GOODS: VLT VIMOS R',
#                             'GOODS: HST ACS B',
#                             'GOODS: HST ACS V',
#                             'GOODS: HST ACS I',
#                             'GOODS: HST ACS Z',
#                             'Hawaii HDF U',
#                             'Hawaii HDF B',
#                             'Hawaii HDF V0201',
#                             'Hawaii HDF V0401',
#                             'Hawaii HDF R',
#                             'Hawaii HDF I',
#                             'Hawaii HDF z',
#                             'Hawaii HDF HK',
#                             'GOODS: HST NICMOS',
#                             'GOODS: VLT ISAAC J',
#                             'GOODS: VLT ISAAC H',
#                             'GOODS: VLT ISAAC Ks',
#                             'HUDF: VLT ISAAC Ks',
#                             'GOODS: Spitzer IRAC 3.6',
#                             'GOODS: Spitzer IRAC 4.5',
#                             'GOODS: Spitzer IRAC 5.8',
#                             'GOODS: Spitzer IRAC 8.0',
#                             'GOODS: Spitzer MIPS 24',
#                             'GOODS: Herschel 100',
#                             'GOODS: Herschel 160',
#                             'GOODS: Herschel 250',
#                             'GOODS: Herschel 350',
#                             'GOODS: Herschel 500',
#                             'CDFS: LESS',
#                             'GOODS: VLA North'],
#  'Allbands:HiPS': ['UltraVista-H',
#                    'UltraVista-J',
#                    'UltraVista-Ks',
#                    'UltraVista-NB118',
#                    'UltraVista-Y',
#                    'CFHTLS-W-u',
#                    'CFHTLS-W-g',
#                    'CFHTLS-W-r',
#                    'CFHTLS-W-i',
#                    'CFHTLS-W-z',
#                    'CFHTLS-D-u',
#                    'CFHTLS-D-g',
#                    'CFHTLS-D-r',
#                    'CFHTLS-D-i',
#                    'CFHTLS-D-z'],
#  'GammaRay': ['Fermi 5',
#               'Fermi 4',
#               'Fermi 3',
#               'Fermi 2',
#               'Fermi 1',
#               'EGRET (3D)',
#               'EGRET <100 MeV',
#               'EGRET >100 MeV',
#               'COMPTEL'],
#  'HardX-ray': ['INT GAL 17-35 Flux',
#                'INT GAL 17-60 Flux',
#                'INT GAL 35-80 Flux',
#                'INTEGRAL/SPI GC',
#                'GRANAT/SIGMA',
#                'RXTE Allsky 3-8keV Flux',
#                'RXTE Allsky 3-20keV Flux',
#                'RXTE Allsky 8-20keV Flux'],
#  'IR:2MASS class=': ['2MASS-J', '2MASS-H', '2MASS-K'],
#  'IR:AKARI class=': ['AKARI N60', 'AKARI WIDE-S', 'AKARI WIDE-L', 'AKARI N160'],
#  'IR:IRAS': ['IRIS  12',
#              'IRIS  25',
#              'IRIS  60',
#              'IRIS 100',
#              'SFD100m',
#              'SFD Dust Map',
#              'IRAS  12 micron',
#              'IRAS  25 micron',
#              'IRAS  60 micron',
#              'IRAS 100 micron'],
#  'IR:Planck': ['Planck 857 I',
#                'Planck 545 I',
#                'Planck 353 I',
#                'Planck 353 Q',
#                'Planck 353 U',
#                'Planck 353 PI',
#                'Planck 353 PA',
#                'Planck 353 PI/I',
#                'Planck 217 I',
#                'Planck 217 Q',
#                'Planck 217 U',
#                'Planck 217 PI',
#                'Planck 217 PA',
#                'Planck 217 PI/I',
#                'Planck 143 I',
#                'Planck 143 Q',
#                'Planck 143 U',
#                'Planck 143 PI',
#                'Planck 143 PA',
#                'Planck 143 PI/I',
#                'Planck 100 I',
#                'Planck 100 Q',
#                'Planck 100 U',
#                'Planck 100 PI',
#                'Planck 100 PA',
#                'Planck 100 PI/I',
#                'Planck 070 I',
#                'Planck 070 Q',
#                'Planck 070 U',
#                'Planck 070 PI',
#                'Planck 070 PA',
#                'Planck 070 PI/I',
#                'Planck 044 I',
#                'Planck 044 Q',
#                'Planck 044 U',
#                'Planck 044 PI',
#                'Planck 044 PA',
#                'Planck 044 PI/I',
#                'Planck 030 I',
#                'Planck 030 Q',
#                'Planck 030 U',
#                'Planck 030 PI',
#                'Planck 030 PA',
#                'Planck 030 PI/I'],
#  'IR:UKIDSS class=': ['UKIDSS-Y',
#                       'UKIDSS-J',
#                       'UKIDSS-H',
#                       'UKIDSS-K',
#                       'UKIDSS-1-0S1'],
#  'IR:WISE class=': ['WISE 3.4', 'WISE 4.6', 'WISE 12', 'WISE 22'],
#  'IR:WMAP&COBE': ['WMAP ILC',
#                   'WMAP Ka',
#                   'WMAP K',
#                   'WMAP Q',
#                   'WMAP V',
#                   'WMAP W',
#                   'COBE DIRBE/AAM',
#                   'COBE DIRBE/ZSMA'],
#  'Optical:DSS class=': ['DSS',
#                         'DSS1 Blue',
#                         'DSS1 Red',
#                         'DSS2 Red',
#                         'DSS2 Blue',
#                         'DSS2 IR'],
#  'Optical:SDSS': ['SDSSg',
#                   'SDSSi',
#                   'SDSSr',
#                   'SDSSu',
#                   'SDSSz',
#                   'SDSSdr7g',
#                   'SDSSdr7i',
#                   'SDSSdr7r',
#                   'SDSSdr7u',
#                   'SDSSdr7z'],
#  'OtherOptical': ['TESS',
#                   'Mellinger Red',
#                   'Mellinger Green',
#                   'Mellinger Blue',
#                   'H-Alpha Comp',
#                   'SHASSA H',
#                   'SHASSA CC',
#                   'SHASSA C',
#                   'SHASSA Sm'],
#  'ROSATDiffuse class=': ['RASS Background 1',
#                          'RASS Background 2',
#                          'RASS Background 3',
#                          'RASS Background 4',
#                          'RASS Background 5',
#                          'RASS Background 6',
#                          'RASS Background 7'],
#  'ROSATw/sources class=': ['RASS-Cnt Soft',
#                            'RASS-Cnt Hard',
#                            'RASS-Cnt Broad',
#                            'PSPC 2.0 Deg-Int',
#                            'PSPC 1.0 Deg-Int',
#                            'PSPC 0.6 Deg-Int',
#                            'HRI'],
#  'Radio:GHz': ['CO',
#                'GB6 (4850MHz)',
#                'VLA FIRST (1.4 GHz)',
#                'NVSS',
#                'Stripe82VLA',
#                '1420MHz (Bonn)',
#                'HI4PI',
#                'EBHIS',
#                'nH'],
#  'Radio:GLEAM class=': ['GLEAM 72-103 MHz',
#                         'GLEAM 103-134 MHz',
#                         'GLEAM 139-170 MHz',
#                         'GLEAM 170-231 MHz'],
#  'Radio:MHz class=': ['SUMSS 843 MHz',
#                       '0408MHz',
#                       'WENSS',
#                       'TGSS ADR1',
#                       'VLSSr',
#                       '0035MHz',
#                       '0022MHz'],
#  'SoftX-ray class=': ['SwiftXRTCnt',
#                       'SwiftXRTExp',
#                       'SwiftXRTInt',
#                       'HEAO 1 A-2'],
#  'SwiftUVOT class=': ['UVOT WHITE Intensity',
#                       'UVOT V Intensity',
#                       'UVOT B Intensity',
#                       'UVOT U Intensity',
#                       'UVOT UVW1 Intensity',
#                       'UVOT UVM2 Intensity',
#                       'UVOT UVW2 Intensity'],
#  'UV': ['GALEX Near UV',
#         'GALEX Far UV',
#         'ROSAT WFC F1',
#         'ROSAT WFC F2',
#         'EUVE 83 A',
#         'EUVE 171 A',
#         'EUVE 405 A',
#         'EUVE 555 A'],
#  'X-ray:SwiftBAT': ['BAT SNR 14-195',
#                     'BAT SNR 14-20',
#                     'BAT SNR 20-24',
#                     'BAT SNR 24-35',
#                     'BAT SNR 35-50',
#                     'BAT SNR 50-75',
#                     'BAT SNR 75-100',
#                     'BAT SNR 100-150',
#                     'BAT SNR 150-195']}
# surveys:  None
# WARNING: AstropyDeprecationWarning: The truth value of a Quantity is ambiguous. In the future this will raise a ValueError. [astropy.units.quantity]
# ['./charts/GDB1.pdf', './charts/GDB2.pdf', './charts/GDB3.pdf', './charts/GDB4.pdf', './charts/GDB5.pdf', './charts/GDB6.pdf', './charts/GDB7.pdf', './charts/GDB8.pdf', './charts/GDB9.pdf', './charts/GDB10.pdf', './charts/GDB11.pdf', './charts/GDB12.pdf', './charts/GDB13.pdf', './charts/GDB14.pdf', './charts/GDB15.pdf', './charts/GDB16.pdf', './charts/GDB17.pdf', './charts/GDB18.pdf', './charts/GDB19.pdf', './charts/GDB20.pdf', './charts/GDB21.pdf', './charts/GDB22.pdf', './charts/GDB23.pdf', './charts/GDB24.pdf', './charts/GDB25.pdf', './charts/GDB26.pdf', './charts/GDB27.pdf', './charts/GDB28.pdf', './charts/GDB29.pdf', './charts/GDB30.pdf', './charts/GDB31.pdf', './charts/GDB32.pdf', './charts/GDB33.pdf', './charts/GDB34.pdf', './charts/GDB35.pdf', './charts/GDB36.pdf', './charts/GDB37.pdf', './charts/GDB38.pdf', './charts/GDB39.pdf', './charts/GDB40.pdf', './charts/GDB41.pdf']
